# %% [markdown]
# <a href="https://colab.research.google.com/github/veeralakshmi-coder/FMML-2024/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:46:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  77.3MB/s    in 0.9s
#
# 2025-03-16 06:46:49 (77.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 34695  1709.09119v1  If someone is looking for a certain publicatio...    cs
# 22990  1712.09988v2  There has been growing interest in how economi...  stat
# 22536  1610.10025v5  We consider the problem of constructing diffus...  stat
# 24585   1407.8497v1  Organ segmentation is a prerequisite for a com...    cs
# 39608  1610.02610v3  Pouring a specific amount of liquid is a chall...    cs
# ...             ...                                                ...   ...
# 12177  1710.00904v1  In today's era of big data, robust least-squar...    cs
# 14771   1208.3001v1  With such increasing popularity and availabili...    cs
# 21715   1010.4236v1  We have developed an efficient algorithm for t...  stat
# 24741   1411.4280v3  Recent state-of-the-art performance on human-b...    cs
# 27809  1704.06040v1  The ability to automatically learn task specif...    cs
#
#                                                    title  year  \
# 34695  Integration of Japanese Papers Into the DBLP D...  2017
# 22990  Orthogonal Machine Learning for Demand Estimat...  2017
# 22536  Function Driven Diffusion for Personalized Cou...  2016
# 24585  A Bottom-Up Approach for Automatic Pancreas Se...  2014
# 39608     Visual Closed-Loop Control for Pouring Liquids  2016
# ...                                                  ...   ...
# 12177  Online and Distributed Robust Regressions unde...  2017
# 14771  More than Word Frequencies: Authorship Attribu...  2012
# 21715  Maximum Likelihood Joint Tracking and Associat...  2010
# 24741  Efficient Object Localization Using Convolutio...  2014
# 27809  Understanding the Mechanisms of Deep Transfer ...  2017
#
#                                                 keywords
# 34695  [publication, searching, publication, continuo...
# 22990  [economists, prediction, accelerate, selection...
# 22536  [constructing, diffusion, operators, dimension...
# 24585  [segmentation, prerequisite, diagnosis, pathol...
# 39608  [challenging, utilizing, estimating, container...
# ...                                                  ...
# 12177  [regression, challenging, considering, adversa...
# 14771  [increasing, popularity, availability, authors...
# 21715  [developed, efficient, algorithm, likelihood, ...
# 24741  [performance, estimation, convolutional, tradi...
# 27809  [automatically, representations, effective, sy...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 34695    [publication, searching, publication, continuo...
# 22990    [economists, prediction, accelerate, selection...
# 22536    [constructing, diffusion, operators, dimension...
# 24585    [segmentation, prerequisite, diagnosis, pathol...
# 39608    [challenging, utilizing, estimating, container...
#                                ...
# 7368     [practical, regularization, encouraging, regul...
# 21625    [estimation, typically, maximizing, objective,...
# 27642    [adaptation, researched, leverages, unsupervis...
# 9632     [algorithm, approximating, nonstandard, poster...
# 11840    [restaurant, nonparametric, hierarchy, hierarc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8826 words.
# Out of those 4589 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd7eaa6c-5f7f-405f-8cc6-3c9a83475a15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd7eaa6c-5f7f-405f-8cc6-3c9a83475a15")) {                    Plotly.newPlot(                        "bd7eaa6c-5f7f-405f-8cc6-3c9a83475a15",                        [{"x":["concerning","nevertheless","searching","publications","languages","publication","especially","important","integration","transcription","remarkable","continuously","collection","processing","automatically","published","estimating","estimators","framework","convergence","sequentially","practitioners","estimation","retaining","partially","asymptotic","inference","dimensional","estimator","desirable","coefficients","treatments","economists","exogenous","orthogonal","parameters","accelerate","selection","properties","dimensionality","treatment","alternative","prediction","equivalent","effectiveness","synthetic","localized","questions","constructing","functions","filtration","resulting","directions","counterfactual","situations","diffusion","pointwise","particularly","individual","personalized","individualized","operators","construct","medication","prerequisite","classifier","respectively","iterative","propagation","quantitative","comparing","presented","clustering","superpixel","segmented","information","abdominal","accuracies","variability","superpixels","extraction","tomography","hierarchical","pathologies","anatomically","classifying","segmentation","automatic","automated","comparable","diagnosis","validation","coefficient","supervised","utilizing","container","knowledge","deviation","challenging","controller","obtaining","generative","representations","adversarially","generation","variables","performance","competitive","illustrate","adversarial","distinguish","inspections","stochastic","usefulness","reconstructions","introduce","discriminative","significant","processes","difference","interventions","represents","continuous","structure","invariant","potential","estimated","multivariate","correlation","frequency","dynamical","simulated","reasoning","challenge","observational","countries","prototype","engineering","intention","diagnostics","expensive","environments","developed","infrastructure","constraints","specialist","electroencephalography","classification","disorders","demonstrate","physicians","architecture","hyperparameters","including","technique","extensively","prohibitively","performed","intervention","significantly","addressed","developing","specialized","computing","interpretation","imaginary","resources","minimizing","essential","footprint","computation","applications","efficient","preserving","temporary","available","efficiently","feedforward","binarized","accomplish","reduction","intermediate","empirical","development","literature","constraint","implementations","prohibitive","redundant","involving","sequential","counterparts","operating","convolutional","parameter","interdisciplinary","underlying","optimization","techniques","generated"],"y":[12,19,40,5,104,6,118,327,47,13,30,20,65,294,188,36,47,12,567,107,17,17,208,6,47,22,199,172,28,33,41,3,0,3,21,234,13,145,183,57,32,105,212,50,201,117,14,67,46,200,1,157,52,5,48,33,3,77,112,16,1,48,96,1,6,159,97,73,81,70,72,183,151,12,19,662,3,27,27,9,128,20,88,3,2,40,177,201,97,80,51,43,23,212,31,3,367,15,242,12,30,115,247,2,143,126,906,124,83,105,31,2,160,33,16,322,97,231,110,56,6,57,125,336,69,178,54,14,65,64,24,72,117,153,9,13,21,56,9,5,61,88,181,12,142,2,1,487,4,563,2,233,9,271,234,28,7,120,10,250,43,60,24,151,67,1,71,46,74,18,141,441,428,48,4,294,145,20,4,15,98,30,141,121,113,95,39,8,22,54,81,19,26,380,132,2,123,329,363,161],"type":"bar"},{"x":["concerning","nevertheless","searching","publications","languages"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4589,), (4589, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Rényi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style=''>Privacy</span> <span style='background-color:rgba(0, 255, 0, 0.40540540540540543);'>Mechanisms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5763546798029557);'>Posterior</span> <span style=''>Sampling</span> <br/><br/><span style=''>Using</span> <span style=''>a</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.30303030303030304);'>definition</span> <span style=''>of</span> <span style=''>Renyi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style=''>Privacy</span> <span style=''>(RDP)</span> <span style=''>we</span> <span style=''>re</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>inherent</span> <span style=''>privacy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>releasing</span> <span style=''>a</span> <span style=''>single</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5763546798029557);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>the</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mitigating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>data</span> <span style=''>points</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>and</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.5340206185567009);'>regression</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>novel</span> <span style=''>RDP</span> <span style='background-color:rgba(0, 255, 0, 0.40540540540540543);'>mechanisms</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>offering</span> <span style=''>a</span> <span style=''>new</span> <span style=''>RDP</span> <span style=''>analysis</span> <span style=''>for</span> <span style=''>an</span> <span style=''>existing</span> <span style=''>method</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>add</span> <span style=''>value</span> <span style=''>to</span> <span style=''>the</span> <span style=''>RDP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>Each</span> <span style=''>method</span> <span style=''>is</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.32653061224489804);'>achieving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>RDP</span> <span style=''>privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>and</span> <span style=''>we</span> <span style=''>offer</span> <span style='background-color:rgba(0, 255,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Comunication</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>on</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>a</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>averaging</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributes</span> <span style=''>the</span> <span style=''>N</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>evenly</span> <span style=''>to</span> <span style=''>nummac</span> <span style=''>machines</span> <span style=''>performs</span> <span style=''>separate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>on</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>and</span> <span style=''>then</span> <span style=''>averages</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>sharp</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>this</span> <span style=''>average</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>combined</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>achieves</span> <span style=''>mean</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>that</span> <span style=''>decays</span> <span style=''>as</span> <span style=''>order(N</span> <span style=''>1(Nm)</span> <span style=''>2)</span> <span style=''>Whenever</span> <span style=''>m</span> <span style=''>le</span> <span style=''>sqrtN</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>best</span> <span style=''>possible</span> <span style=''>rate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achievable</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>centralized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>having</span> <span style=''>access</span> <span style=''>to</span> <span style=''>all</span> <span style=''>totalnumobs</span> <span style=''>samples</span> <span style=''>The</span> <span style=''>second</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Parameter</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.7647058823529411);'>Semiparametric</span> <span style='background-color:rgba(255, 0, 0, 0.5340206185567009);'>Regression</span> <span style=''>Approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovering</span> <span style=''>Latent</span> <span style=''>Task</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Parametrizations</span> <br/><br/><span style=''>Control</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>often</span> <span style=''>feature</span> <span style=''>tasks</span> <span style=''>with</span> <span style=''>similar</span> <span style=''>but</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>dynamics</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Parameter</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style=''>Process</span> <span style=''>(HiP</span> <span style=''>MDP)</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrizes</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>with</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.36648250460405146);'>dimensional</span> <span style=''>set</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>factors</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.7647058823529411);'>semiparametric</span> <span style='background-color:rgba(255, 0, 0, 0.5340206185567009);'>regression</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>from</span> <span style=''>data</span> <span style=''>In</span> <span style=''>the</span> <span style=''>control</span> <span style=''>setting</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>learned</span> <span style=''>HiP</span> <span style=''>MDP</span> <span style=''>rapidly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifies</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>new</span> <span style=''>task</span> <span style=''>instance</span> <span style=''>allowing</span> <span style=''>an</span> <span style=''>agent</span> <span style=''>to</span> <span style=''>flexibly</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.3953488372093024);'>variations</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MILJS</span> <span style=''>Brand</span> <span style=''>New</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>JavaScript</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Libraries</span> <span style=''>for</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Calculation</span> <span style=''>and</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>MILJS</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>platform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>scalable</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>JavaScript</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>libraries</span> <span style=''>for</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculation</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Our</span> <span style=''>core</span> <span style=''>library</span> <span style=''>offering</span> <span style=''>a</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculation</span> <span style=''>is</span> <span style=''>called</span> <span style=''>Sushi</span> <span style=''>which</span> <span style=''>exhibits</span> <span style=''>far</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>than</span> <span style=''>any</span> <span style=''>other</span> <span style=''>leading</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>libraries</span> <span style=''>written</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>JavaScript</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Especially</span> <span style=''>our</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplication</span> <span style=''>is</span> <span style=''>177</span> <span style=''>times</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>the</span> <span style=''>fastest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>JavaScript</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>Sushi</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>library</span> <span style=''>called</span> <span style=''>Tempura</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>which</span> <span style=''>supports</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>research</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>Soba</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>library</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementations</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>libraries</span> <span style=''>are</span> <span style=''>clearly</span> <span style=''>written</span> <span style=''>properly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>documented</span> <span style=''>and</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07188841201716738)
# 	processing (0.10515021459227468)
# 	knowledge (0.13125894134477825)
# 	representation (0.13662374821173104)
# 	information (0.23676680972818312)
# 	detection (0.1223175965665236)
# 	experimental (0.1452074391988555)
# 	different (0.26645207439198854)
# 	recognition (0.13340486409155938)
# 	convolutional (0.13590844062947066)
#
# Some Statistics words are:
# 	algorithm (0.3837325349301397)
# 	convergence (0.12225548902195608)
# 	statistical (0.14171656686626746)
# 	variables (0.13522954091816367)
# 	estimation (0.1751497005988024)
# 	distribution (0.1781437125748503)
# 	theoretical (0.16666666666666666)
# 	dimensional (0.18512974051896208)
# 	inference (0.19710578842315368)
# 	regression (0.18562874251497005)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="77258215-7b9c-4a16-9733-051314ad1f6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77258215-7b9c-4a16-9733-051314ad1f6c")) {                    Plotly.newPlot(                        "77258215-7b9c-4a16-9733-051314ad1f6c",                        [{"x":["concerning","nevertheless","searching","publications","languages","publication","especially","important","integration","transcription","remarkable","continuously","collection","processing","automatically","published","estimating","estimators","framework","convergence","sequentially","practitioners","estimation","retaining","partially","asymptotic","inference","dimensional","estimator","desirable","coefficients","treatments","economists","exogenous","orthogonal","parameters","accelerate","selection","properties","dimensionality","treatment","alternative","prediction","equivalent","effectiveness","synthetic","localized","questions","constructing","functions","filtration","resulting","directions","counterfactual","situations","diffusion","pointwise","particularly","individual","personalized","individualized","operators","construct","medication","prerequisite","classifier","respectively","iterative","propagation","quantitative","comparing","presented","clustering","superpixel","segmented","information","abdominal","accuracies","variability","superpixels","extraction","tomography","hierarchical","pathologies","anatomically","classifying","segmentation","automatic","automated","comparable","diagnosis","validation","coefficient","supervised","utilizing","container","knowledge","deviation","challenging","controller","obtaining","generative","representations","adversarially","generation","variables","performance","competitive","illustrate","adversarial","distinguish","inspections","stochastic","usefulness","reconstructions","introduce","discriminative","significant","processes","difference","interventions","represents","continuous","structure","invariant","potential","estimated","multivariate","correlation","frequency","dynamical","simulated","reasoning","challenge","observational","countries","prototype","engineering","intention","diagnostics","expensive","environments","developed","infrastructure","constraints","specialist","electroencephalography","classification","disorders","demonstrate","physicians","architecture","hyperparameters","including","technique","extensively","prohibitively","performed","intervention","significantly","addressed","developing","specialized","computing","interpretation","imaginary","resources","minimizing","essential","footprint","computation","applications","efficient","preserving","temporary","available","efficiently","feedforward","binarized","accomplish","reduction","intermediate","empirical","development","literature","constraint","implementations","prohibitive","redundant","involving","sequential","counterparts","operating","convolutional","parameter","interdisciplinary","underlying","optimization","techniques","generated","probability","challenges","generally","biological","statistics","disparate","emphasized","opportunities","diversity","differences","motivated","similarities","interpretability","empirically","attributes","conditional","different","sociology","inhibited","probabilistic","interactions","theoretical","highlights","fundamental","philosophical","altogether","individuals","affective","providing","implement","understood","consistently","emotional","traditional","considerable","improvements","innovations","implications","following","intensity","predicting","ambiguity","tailoring","recurrent","analyzing","recognition","dimensions","complexity","materials","outperforms","narrative","undertaking","embeddings","controllable","appear ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	economists
# 	sociology
# 	manageable
# 	discretised
# 	descendant
# 	spectroscopy
# 	eigenstructures
# 	detailing
# 	timeseries
# 	dendrogram
# 	eigenfunction
# 	abnormality
# 	emphmulti
# 	contingent
# 	broadening
# 	temperatures
# 	quadrature
# 	oscillations
# 	terminate
# 	distributionally
# Some words which never appear in Statistics papers:
# 	prerequisite
# 	superpixel
# 	abdominal
# 	superpixels
# 	pathologies
# 	container
# 	temporary
# 	affective
# 	undertaking
# 	personality
# 	experimented
# 	polytrees
# 	pharmaceutical
# 	geolocation
# 	objectness
# 	avalanche
# 	nondeterminism
# 	nondeterministic
# 	associating
# 	occlusions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072291007404222e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
